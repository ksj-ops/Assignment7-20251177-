# %% [markdown]
# <a href="https://colab.research.google.com/github/ksj-ops/Assignment7-20251177-/blob/main/assignment7(20251177).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1
# 최악의 경우: O(n)
# 최선의 경우: O(1)

# %% [markdown]
# #2
# 삽입한 경우라면 17,30,70 중에 삽입해야하는데 삽입 전이 균형인 것이 불가능이다. 따라서 10의 왼쪽 자식을 삭제하면서 균형이 깨진 것이다.

# %% [markdown]
# #3
# 17을 하면서 깨졌거나 55의 자식노드를 삭제해서 깨졌을 것이다.

# %% [markdown]
# #4
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #5
# LR타입, RL타입

# %% [markdown]
# #6
# AVL트리에서 수선 후에 높이가 반드시 낮아진다는 것은 맞는 주장이 아니다.

# %% [markdown]
# #7
# 3회 이상 수선이 필요한 경우가 발생할 수 있음

# %% [markdown]
# #8
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #9
# 1. 삽입한 노드 p의 부모인 p^2이 레드이고 형제노드도 레드일때 둘 다 블랙으로 바꾸고 p^3은 레드로 바꾼다.
# 2. p^4이 레드면 p^3,p^4이 둘 다 레드이기때문에 성질 3이 또 깨진다. 위의 과정을 반복한다
#
# 3. p^4의 형제노드가 레드이면 둘 다 블랙으로 바꾸고 p^5은 레드로 바꾼다.
# 4. p^6이 레드면 p^5,p^6이 둘 다 레드이기 때문에 성질 3이 깨진다.
#
# 5. p^6의 형제노드가 레드이면 둘 다 블랙으로 바꾸고 p^7은 레드로 바꾼다. 위의 과정이 계속 루트까지 이어질 수 있다

# %% [markdown]
# #10
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #11
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #12
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #13
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #14
# 직후 원소는 오른쪽 서브트리의 최솟값인데, 최솟값을 찾으려면 끝까지 내려가야 하고 B-트리에서 끝은 항상 리프이기 때문이다.

# %% [markdown]
# #16
# 내부 노드의 키가 n개면 → 자식이 n+1개
# 즉 내부 노드 키 수와 자식 수는 항상 1 차이이다.

# %% [markdown]
# #17
# 오버플로우는 생기지 않는다.
